# %%
from LoadFile import *

# %%
load_data()
remove_an_necessary_column()
merge_data()
remove_2017_and_2016()
case_fold()
remove_short_reviews()
remove_redundant_review()

# %%
x = datas['./data/raw/2017.xlsx']

# %%
parse_into_xml()
save_data()

# %%
x
# Out:
# ['layanan sangat baik',
#  'beberapa pengajar terkadang tidak datang tepat waktu tetapi masih pada batas sesuai dengan kontrak kuliah yang disampaikan',
#  'beberapa matakuliah  kondisi ruangannya tidak kondusif',
#  'cara mengajarnya baik, menyampaikan materi dengan jelas',
#  'tidak ada suara yg mengganggu, kelas bersih',
#  'adanya laboratorium, tempat olahraga, tempat ibadah, tempat berkreasi',
#  'ini yang kurang baik',
#  'sudah cukup, namun masih perlu adanya perbaikan/penambahan seperti infocus, ac, lemari dll',
#  'tekadang mendapatkan dosen yangsl sulit dimengerti',
#  'beberapa ruangan meskipun ada ac nya tetapi masih panas',
#  'menurut saya, para dosen sudah cukup berkualitas dari penyamlaian ataupun ilmu',
#  'menurut saya. kondisi perkuliahaan saat in sudah jauh lebih bail dari tahun sebelumnya. sbg contoh ac yang sudah aktif',
#  'menurut saya. sarana dan prasarana do kampus masih sangat minim. sbg contoh ruang untuk belajar bagi mahasiswa diluar kelas',
# ...

# %%
k = './data/2019.xlsx'
re.sub('\D', '', k)

# %%
'./data/2019.xlsx'.split('.')
